# %% [markdown]
# ### All Techniques Of Hyper Parameter Optimization
#
# 1. GridSearchCV
# 2. RandomizedSearchCV
# 3. Bayesian Optimization -Automate Hyperparameter Tuning (Hyperopt)
# 4. Sequential Model Based Optimization(Tuning a scikit-learn estimator with skopt)
# 4. Optuna- Automate Hyperparameter Tuning
# 5. Genetic Algorithms (TPOT Classifier)
#
# ###### References
# - https://github.com/fmfn/BayesianOptimization
# - https://github.com/hyperopt/hyperopt
# - https://www.jeremyjordan.me/hyperparameter-tuning/
# - https://optuna.org/
# - https://towardsdatascience.com/hyperparameters-optimization-526348bb8e2d(By Pier Paolo Ippolito )
# - https://scikit-optimize.github.io/stable/auto_examples/hyperparameter-optimization.html

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df['Glucose'].unique()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 126,  99, 196, 119, 143, 147,  97,
#        145, 117, 109, 158,  88,  92, 122, 138, 102,  90, 111, 180, 133,
#        106, 171, 159, 146,  71, 105, 101, 176, 150,  73, 187,  84,  44,
#        141, 114,  95, 129,  79,   0,  62, 131, 112, 113,  74,  83, 136,
#         80, 123,  81, 134, 142, 144,  93, 163, 151,  96, 155,  76, 160,
#        124, 162, 132, 120, 173, 170, 128, 108, 154,  57, 156, 153, 188,
#        152, 104,  87,  75, 179, 130, 194, 181, 135, 184, 140, 177, 164,
#         91, 165,  86, 193, 191, 161, 167,  77, 182, 157, 178,  61,  98,
#        127,  82,  72, 172,  94, 175, 195,  68, 186, 198, 121,  67, 174,
#        199,  56, 169, 149,  65, 190], dtype=int64)

# %%
#zero glucose values
import numpy as np
df['Glucose']=np.where(df['Glucose']==0,df['Glucose'].median(),df['Glucose'])
df['Insulin']=np.where(df['Insulin']==0,df['Insulin'].median(),df['Insulin'])
df['SkinThickness']=np.where(df['SkinThickness']==0,df['SkinThickness'].median(),df['SkinThickness'])
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#### Independent And Dependent features
X=df.drop('Outcome',axis=1)
y=df['Outcome']

# %%
pd.DataFrame(X,columns=df.columns[:-1])
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72           35.0     30.5  33.6
# 1              1     85.0             66           29.0     30.5  26.6
# 2              8    183.0             64           23.0     30.5  23.3
# 3              1     89.0             66           23.0     94.0  28.1
# 4              0    137.0             40           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76           48.0    180.0  32.9
# 764            2    122.0             70           27.0     30.5  36.8
# 765            5    121.0             72           23.0    112.0  26.2
# 766            1    126.0             60           23.0     30.5  30.1
# 767            1     93.0             70           31.0     30.5  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
print(X.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0             72           35.0     30.5  33.6
# 1            1     85.0             66           29.0     30.5  26.6
# 2            8    183.0             64           23.0     30.5  23.3
# 3            1     89.0             66           23.0     94.0  28.1
# 4            0    137.0             40           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
print(y.head())
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
#### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=33)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_classifier=RandomForestClassifier(n_estimators=10).fit(X_train,y_train)
prediction=rf_classifier.predict(X_test)

# %%
y.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
print(confusion_matrix(y_test,prediction))
print(accuracy_score(y_test,prediction))
print(classification_report(y_test,prediction))
# Out:
# [[81 18]
#  [32 23]]
# 0.6753246753246753
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.76        99
#            1       0.56      0.42      0.48        55
#
#     accuracy                           0.68       154
#    macro avg       0.64      0.62      0.62       154
# weighted avg       0.66      0.68      0.66       154

# %% [markdown]
# The main parameters used by a Random Forest Classifier are:
#
# - criterion = the function used to evaluate the quality of a split.
# - max_depth = maximum number of levels allowed in each tree.
# - max_features = maximum number of features considered when splitting a node.
# - min_samples_leaf = minimum number of samples which can be stored in a tree leaf.
# - min_samples_split = minimum number of samples necessary in a node to cause node splitting.
# - n_estimators = number of trees in the ensamble.

# %%
### Manual Hyperparameter Tuning
model=RandomForestClassifier(n_estimators=300,criterion='entropy',
                             max_features='sqrt',min_samples_leaf=10,random_state=100).fit(X_train,y_train)
predictions=model.predict(X_test)
print(confusion_matrix(y_test,predictions))
print(accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[87 12]
#  [28 27]]
# 0.7402597402597403
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        99
#            1       0.69      0.49      0.57        55
#
#     accuracy                           0.74       154
#    macro avg       0.72      0.68      0.69       154
# weighted avg       0.73      0.74      0.73       154

# %% [markdown]
# ##### Randomized Search Cv

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(random_grid)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
rf=RandomForestClassifier()
rf_randomcv=RandomizedSearchCV(estimator=rf,param_distributions=random_grid,n_iter=100,cv=3,verbose=2,
                               random_state=100,n_jobs=-1)
### fit the randomized model
rf_randomcv.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 2000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_features': 'log2',
#  'max_depth': 1000,
#  'criterion': 'gini'}

# %%
rf_randomcv
# Out:
# RandomizedSearchCV(cv=3, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [10, 120, 230, 340, 450,
#                                                       560, 670, 780, 890,
#                                                       1000],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]},
#                    random_state=100, verbose=2)

# %%
best_random_grid=rf_randomcv.best_estimator_

# %%
from sklearn.metrics import accuracy_score
y_pred=best_random_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[86 13]
#  [26 29]]
# Accuracy Score 0.7467532467532467
# Classification report:               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        99
#            1       0.69      0.53      0.60        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.70      0.71       154
# weighted avg       0.74      0.75      0.74       154

# %% [markdown]
# #### GridSearch CV

# %%
rf_randomcv.best_params_
# Out:
# {'n_estimators': 2000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 8,
#  'max_features': 'log2',
#  'max_depth': 1000,
#  'criterion': 'gini'}

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': [rf_randomcv.best_params_['criterion']],
    'max_depth': [rf_randomcv.best_params_['max_depth']],
    'max_features': [rf_randomcv.best_params_['max_features']],
    'min_samples_leaf': [rf_randomcv.best_params_['min_samples_leaf'], 
                         rf_randomcv.best_params_['min_samples_leaf']+2, 
                         rf_randomcv.best_params_['min_samples_leaf'] + 4],
    'min_samples_split': [rf_randomcv.best_params_['min_samples_split'] - 2,
                          rf_randomcv.best_params_['min_samples_split'] - 1,
                          rf_randomcv.best_params_['min_samples_split'], 
                          rf_randomcv.best_params_['min_samples_split'] +1,
                          rf_randomcv.best_params_['min_samples_split'] + 2],
    'n_estimators': [rf_randomcv.best_params_['n_estimators'] - 200, rf_randomcv.best_params_['n_estimators'] - 100, 
                     rf_randomcv.best_params_['n_estimators'], 
                     rf_randomcv.best_params_['n_estimators'] + 100, rf_randomcv.best_params_['n_estimators'] + 200]
}

print(param_grid)
# Out:
# {'criterion': ['gini'], 'max_depth': [1000], 'max_features': ['log2'], 'min_samples_leaf': [8, 10, 12], 'min_samples_split': [0, 1, 2, 3, 4], 'n_estimators': [1800, 1900, 2000, 2100, 2200]}

# %%
#### Fit the grid_search to the data
rf=RandomForestClassifier()
grid_search=GridSearchCV(estimator=rf,param_grid=param_grid,cv=10,n_jobs=-1,verbose=2)
grid_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 75 candidates, totalling 750 fits
# GridSearchCV(cv=10, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini'], 'max_depth': [1000],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [8, 10, 12],
#                          'min_samples_split': [0, 1, 2, 3, 4],
#                          'n_estimators': [1800, 1900, 2000, 2100, 2200]},
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_depth=1000, max_features='log2', min_samples_leaf=8,
#                        min_samples_split=3, n_estimators=1800)

# %%
best_grid=grid_search.best_estimator_

# %%
best_grid
# Out:
# RandomForestClassifier(max_depth=1000, max_features='log2', min_samples_leaf=8,
#                        min_samples_split=3, n_estimators=1800)

# %%
y_pred=best_grid.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print("Accuracy Score {}".format(accuracy_score(y_test,y_pred)))
print("Classification report: {}".format(classification_report(y_test,y_pred)))
# Out:
# [[87 12]
#  [27 28]]
# Accuracy Score 0.7467532467532467
# Classification report:               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82        99
#            1       0.70      0.51      0.59        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.69      0.70       154
# weighted avg       0.74      0.75      0.74       154

# %% [markdown]
# ### Automated Hyperparameter Tuning
# Automated Hyperparameter Tuning can be done by using techniques such as
# - Bayesian Optimization
# - Gradient Descent
# - Evolutionary Algorithms

# %%
pip install hyperopt
# Out:
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (1.13.1)
# Requirement already satisfied: six in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (3.2.1)
# Collecting future (from hyperopt)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tqdm in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (4.66.4)
# Requirement already satisfied: cloudpickle in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (2.2.1)
# Requirement already satisfied: py4j in c:\users\mysel\anaconda3\lib\site-packages (from hyperopt) (0.10.9.7)
# Requirement already satisfied: colorama in c:\users\mysel\anaconda3\lib\site-packages (from tqdm->hyperopt) (0.4.6)
# Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.6 MB 2.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.7/1.6 MB 6.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.9/1.6 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 5.1 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.4 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    -------------------------- ------------ 337.9/491.3 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  481.3/491.3 kB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: future, hyperopt
# Successfully installed future-1.0.0 hyperopt-0.2.7
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Bayesian Optimization
# Bayesian optimization uses probability to find the minimum of a function. The final aim is to find the input value to a function which can gives us the lowest possible output value.It usually performs better than random,grid and manual search providing better performance in the testing phase and reduced optimization time.
# In Hyperopt, Bayesian Optimization can be implemented giving 3 three main parameters to the function fmin.
#
# - Objective Function = defines the loss function to minimize.
# - Domain Space = defines the range of input values to test (in Bayesian Optimization this space creates a probability distribution for each of the used Hyperparameters).
# - Optimization Algorithm = defines the search algorithm to use to select the best input values to use in each new iteration.

# %%
from hyperopt import hp,fmin,tpe,STATUS_OK,Trials

# %%
space = {
    'criterion': hp.choice('criterion', ['gini', 'entropy']),
    'max_depth': hp.quniform('max_depth', 1, 1000, 1),  # Ensure max_depth is an integer
    'max_features': hp.choice('max_features', [None, 'sqrt', 'log2']),  # 'auto' replaced with None
    'min_samples_leaf': hp.quniform('min_samples_leaf', 1, 5, 1),  # Make sure this returns an integer
    'min_samples_split': hp.quniform('min_samples_split', 2, 10, 1),  # Make sure this returns an integer
    'n_estimators': hp.choice('n_estimators', range(100, 1000, 100)),  # Choose number of trees
}

# %%
space
# Out:
# {'criterion': <hyperopt.pyll.base.Apply at 0x2298267ec60>,
#  'max_depth': <hyperopt.pyll.base.Apply at 0x2298267faa0>,
#  'max_features': <hyperopt.pyll.base.Apply at 0x2298267f080>,
#  'min_samples_leaf': <hyperopt.pyll.base.Apply at 0x2298267f650>,
#  'min_samples_split': <hyperopt.pyll.base.Apply at 0x2298267f560>,
#  'n_estimators': <hyperopt.pyll.base.Apply at 0x2298267f920>}

# %%
def objective(space):
    model = RandomForestClassifier(
        criterion=space['criterion'],
        max_depth=int(space['max_depth']),  # Ensure max_depth is an integer
        max_features=space['max_features'],
        min_samples_leaf=int(space['min_samples_leaf']),  # Convert to integer
        min_samples_split=int(space['min_samples_split']),  # Convert to integer
        n_estimators=space['n_estimators']
    )

    accuracy = cross_val_score(model, X_train, y_train, cv=5).mean()
    
    return {'loss': -accuracy, 'status': STATUS_OK}

# %%
from sklearn.model_selection import cross_val_score
trials = Trials()
best = fmin(fn= objective,
            space= space,
            algo= tpe.suggest,
            max_evals = 80,
            trials= trials)
best
# Out:
# 100%|███████████████████████████████████████████████| 80/80 [17:29<00:00, 13.12s/trial, best loss: -0.7801546048247368]
# {'criterion': 1,
#  'max_depth': 302.0,
#  'max_features': 2,
#  'min_samples_leaf': 5.0,
#  'min_samples_split': 8.0,
#  'n_estimators': 5}

# %%
crit = {0: 'entropy', 1: 'gini'}
feat = {0: 'auto', 1: 'sqrt', 2: 'log2', 3: None}
est = {0: 10, 1: 50, 2: 300, 3: 750, 4: 1200,5:1300,6:1500}


print(crit[best['criterion']])
print(feat[best['max_features']])
print(est[best['n_estimators']])
# Out:
# gini
# log2
# 1300

# %%
best['max_depth']

# %%
best['min_samples_leaf']

# %%
best['min_samples_split']
# Out:
# 8.0

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
trainedforest = RandomForestClassifier(criterion = crit[best['criterion']], max_depth = 302, 
                                       max_features = feat[best['max_features']], 
                                       min_samples_leaf = 5, 
                                       min_samples_split = 8, 
                                       n_estimators = est[best['n_estimators']]).fit(X_train,y_train)
predictionforest = trainedforest.predict(X_test)
print(confusion_matrix(y_test,predictionforest))
print(accuracy_score(y_test,predictionforest))
print(classification_report(y_test,predictionforest))
acc5 = accuracy_score(y_test,predictionforest)
# Out:
# [[85 14]
#  [23 32]]
# 0.7597402597402597
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82        99
#            1       0.70      0.58      0.63        55
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.72      0.73       154
# weighted avg       0.75      0.76      0.75       154

# %% [markdown]
# #### Genetic Algorithms
# Genetic Algorithms tries to apply natural selection mechanisms to Machine Learning contexts.
#
# Let's immagine we create a population of N Machine Learning models with some predifined Hyperparameters. We can then calculate the accuracy of each model and decide to keep just half of the models (the ones that performs best). We can now generate some offsprings having similar Hyperparameters to the ones of the best models so that go get again a population of N models. At this point we can again caltulate the accuracy of each model and repeate the cycle for a defined number of generations. In this way, just the best models will survive at the end of the process.

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 1000,10)]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]
# Create the random grid
param = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
              'criterion':['entropy','gini']}
print(param)
# Out:
# {'n_estimators': [200, 400, 600, 800, 1000, 1200, 1400, 1600, 1800, 2000], 'max_features': ['auto', 'sqrt', 'log2'], 'max_depth': [10, 120, 230, 340, 450, 560, 670, 780, 890, 1000], 'min_samples_split': [2, 5, 10, 14], 'min_samples_leaf': [1, 2, 4, 6, 8], 'criterion': ['entropy', 'gini']}

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
from tpot import TPOTClassifier


tpot_classifier = TPOTClassifier(generations= 5, population_size= 24, offspring_size= 12,
                                 verbosity= 2, early_stop= 12,
                                 config_dict={'sklearn.ensemble.RandomForestClassifier': param}, 
                                 cv = 4, scoring = 'accuracy')
tpot_classifier.fit(X_train,y_train)
# Out:
# Optimization Progress:   0%|          | 0/84 [00:00<?, ?pipeline/s]
# Generation 1 - Current best internal CV score: 0.7818309141838553
#
# Generation 2 - Current best internal CV score: 0.7818309141838553
#
# Generation 3 - Current best internal CV score: 0.7818309141838553
#
# Generation 4 - Current best internal CV score: 0.7818309141838553
#
# Generation 5 - Current best internal CV score: 0.7818309141838553
#
# Best pipeline: RandomForestClassifier(input_matrix, criterion=gini, max_depth=120, max_features=log2, min_samples_leaf=6, min_samples_split=14, n_estimators=1400)
# TPOTClassifier(config_dict={'sklearn.ensemble.RandomForestClassifier': {'criterion': ['entropy',
#                                                                                       'gini'],
#                                                                         'max_depth': [10,
#                                                                                       120,
#                                                                                       230,
#                                                                                       340,
#                                                                                       450,
#                                                                                       560,
#                                                                                       670,
#                                                                                       780,
#                                                                                       890,
#                                                                                       1000],
#                                                                         'max_features': ['auto',
#                                                                                          'sqrt',
#                                                                                          'log2'],
#                                                                         'min_samples_leaf': [1,
#                                                                                              2,
#                                                                                              4,
#                                                                                              6,
#                                                                                              8],
#                                                                         'min_samples_split': [2,
#                                                                                               5,
#                                                                                               10,
#                                                                                               14],
#                                                                         'n_estimators': [200,
#                                                                                          400,
#                                                                                          600,
#                                                                                          800,
#                                                                                          1000,
#                                                                                          1200,
#                                                                                          1400,
#                                                                                          1600,
#                                                                                          1800,
#                                                                                          2000]}},
#                cv=4, early_stop=12, generations=5, offspring_size=12,
#                population_size=24, scoring='accuracy', verbosity=2)

# %%
accuracy = tpot_classifier.score(X_test, y_test)
print(accuracy)
# Out:
# 0.7532467532467533

# %% [markdown]
# ### Optimize hyperparameters of the model using Optuna
#
# The hyperparameters of the above algorithm are `n_estimators` and `max_depth` for which we can try different values to see if the model accuracy can be improved. The `objective` function is modified to accept a trial object. This trial has several methods for sampling hyperparameters. We create a study to run the hyperparameter optimization and finally read the best hyperparameters.

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.2-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\mysel\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mysel\anaconda3\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\mysel\anaconda3\lib\site-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in c:\users\mysel\anaconda3\lib\site-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in c:\users\mysel\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in c:\users\mysel\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mysel\anaconda3\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\mysel\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\mysel\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# Downloading optuna-4.0.0-py3-none-any.whl (362 kB)
#    ---------------------------------------- 0.0/362.8 kB ? eta -:--:--
#    ---------------------------------------- 362.8/362.8 kB 7.5 MB/s eta 0:00:00
# Downloading alembic-1.13.2-py3-none-any.whl (232 kB)
#    ---------------------------------------- 0.0/233.0 kB ? eta -:--:--
#    --------------------------------------- 233.0/233.0 kB 14.8 MB/s eta 0:00:00
# Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB ? eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.2 colorlog-6.8.2 optuna-4.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
import sklearn.svm
def objective(trial):

    classifier = trial.suggest_categorical('classifier', ['RandomForest', 'SVC'])
    
    if classifier == 'RandomForest':
        n_estimators = trial.suggest_int('n_estimators', 200, 2000,10)
        max_depth = int(trial.suggest_float('max_depth', 10, 100, log=True))

        clf = sklearn.ensemble.RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth)
    else:
        c = trial.suggest_float('svc_c', 1e-10, 1e10, log=True)
        
        clf = sklearn.svm.SVC(C=c, gamma='auto')

    return sklearn.model_selection.cross_val_score(
        clf,X_train,y_train, n_jobs=-1, cv=3).mean()

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)

trial = study.best_trial

print('Accuracy: {}'.format(trial.value))
print("Best hyperparameters: {}".format(trial.params))
# Out:
# [I 2024-09-15 12:16:12,272] A new study created in memory with name: no-name-2b72003c-bc55-4b59-9466-588d13098357
# [I 2024-09-15 12:16:16,045] Trial 0 finished with value: 0.7638928742228598 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1100, 'max_depth': 27.825337891714828}. Best is trial 0 with value: 0.7638928742228598.
# [I 2024-09-15 12:16:18,092] Trial 1 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 660, 'max_depth': 50.28653436636504}. Best is trial 1 with value: 0.7703969392635103.
# [I 2024-09-15 12:16:19,249] Trial 2 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 1480695.6140354492}. Best is trial 1 with value: 0.7703969392635103.
# [I 2024-09-15 12:16:20,386] Trial 3 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 107.74602307119392}. Best is trial 1 with value: 0.7703969392635103.
# [I 2024-09-15 12:16:23,715] Trial 4 finished with value: 0.7638849035549179 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1280, 'max_depth': 21.4206563136292}. Best is trial 1 with value: 0.7703969392635103.
# [I 2024-09-15 12:16:25,268] Trial 5 finished with value: 0.772030926191615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 23.01466917944976}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:30,556] Trial 6 finished with value: 0.7655188904830225 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1910, 'max_depth': 22.096811978950953}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:30,625] Trial 7 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 985327.1691876879}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:30,674] Trial 8 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 1.1330572456235526e-06}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:30,726] Trial 9 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 0.0007751975383143105}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:31,297] Trial 10 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 210, 'max_depth': 12.962091915922855}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:33,091] Trial 11 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 610, 'max_depth': 75.1943022206605}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:34,567] Trial 12 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 580, 'max_depth': 90.75903742770116}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:36,381] Trial 13 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 710, 'max_depth': 49.773046646384536}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:37,260] Trial 14 finished with value: 0.7720229555236728 and parameters: {'classifier': 'RandomForest', 'n_estimators': 320, 'max_depth': 94.90370517353126}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:37,935] Trial 15 finished with value: 0.7703809979276263 and parameters: {'classifier': 'RandomForest', 'n_estimators': 250, 'max_depth': 13.81872391507128}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:40,335] Trial 16 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 940, 'max_depth': 38.70100005830369}. Best is trial 5 with value: 0.772030926191615.
# [I 2024-09-15 12:16:44,028] Trial 17 finished with value: 0.7720468675274988 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1450, 'max_depth': 10.017214976697632}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:16:48,160] Trial 18 finished with value: 0.7720149848557308 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1620, 'max_depth': 15.037209101136082}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:16:51,732] Trial 19 finished with value: 0.7720229555236728 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1400, 'max_depth': 10.06446639950667}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:16:55,924] Trial 20 finished with value: 0.767136936075243 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1670, 'max_depth': 19.397816971187236}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:16:57,026] Trial 21 finished with value: 0.7687709230033476 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 31.988203365838324}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:16:59,452] Trial 22 finished with value: 0.7638849035549179 and parameters: {'classifier': 'RandomForest', 'n_estimators': 930, 'max_depth': 67.0855675715752}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:00,517] Trial 23 finished with value: 0.767136936075243 and parameters: {'classifier': 'RandomForest', 'n_estimators': 420, 'max_depth': 10.584940354556412}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:02,661] Trial 24 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 860, 'max_depth': 17.867972379841092}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:06,112] Trial 25 finished with value: 0.7687709230033476 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1350, 'max_depth': 25.853478132560827}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:06,168] Trial 26 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 7.751938300200428e-09}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:07,366] Trial 27 finished with value: 0.772030926191615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 450, 'max_depth': 39.21189570657323}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:10,377] Trial 28 finished with value: 0.7720468675274988 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1180, 'max_depth': 39.232448322377685}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:13,344] Trial 29 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1170, 'max_depth': 47.8734943141688}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:17,213] Trial 30 finished with value: 0.7671528774111271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1490, 'max_depth': 34.4317660265904}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:20,001] Trial 31 finished with value: 0.7671528774111271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1100, 'max_depth': 43.35150468316941}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:22,036] Trial 32 finished with value: 0.767136936075243 and parameters: {'classifier': 'RandomForest', 'n_estimators': 800, 'max_depth': 56.53736736743627}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:23,378] Trial 33 finished with value: 0.7622588872947552 and parameters: {'classifier': 'RandomForest', 'n_estimators': 510, 'max_depth': 37.726062375918225}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:27,281] Trial 34 finished with value: 0.7704288219352783 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1510, 'max_depth': 27.110984268067394}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:27,352] Trial 35 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 5735583587.5090275}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:30,491] Trial 36 finished with value: 0.7655188904830225 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1220, 'max_depth': 60.84706713296087}. Best is trial 17 with value: 0.7720468675274988.
# [I 2024-09-15 12:17:33,033] Trial 37 finished with value: 0.7736649131197195 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1000, 'max_depth': 29.79839414453882}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:33,104] Trial 38 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 2.6094544653330427}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:35,673] Trial 39 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1020, 'max_depth': 28.544496289841785}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:35,745] Trial 40 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 7.063144192912599e-10}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:38,654] Trial 41 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1100, 'max_depth': 39.37745902215909}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:40,720] Trial 42 finished with value: 0.7655268611509646 and parameters: {'classifier': 'RandomForest', 'n_estimators': 810, 'max_depth': 23.403490829186428}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:44,048] Trial 43 finished with value: 0.7638769328869759 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1310, 'max_depth': 31.247877918231573}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:48,776] Trial 44 finished with value: 0.767144906743185 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1850, 'max_depth': 45.05365184136431}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:50,023] Trial 45 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 17.306766490466874}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:51,898] Trial 46 finished with value: 0.7655507731547905 and parameters: {'classifier': 'RandomForest', 'n_estimators': 710, 'max_depth': 24.602147398046327}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:54,916] Trial 47 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1190, 'max_depth': 12.314659805932218}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:56,385] Trial 48 finished with value: 0.767144906743185 and parameters: {'classifier': 'RandomForest', 'n_estimators': 600, 'max_depth': 35.107709039622605}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:56,441] Trial 49 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 7.800320795677526e-05}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:59,024] Trial 50 finished with value: 0.7671528774111271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1020, 'max_depth': 29.373435194616697}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:17:59,854] Trial 51 finished with value: 0.7639167862266859 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 75.18372995111635}. Best is trial 37 with value: 0.7736649131197195.
# [I 2024-09-15 12:18:00,715] Trial 52 finished with value: 0.7736728837876615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 330, 'max_depth': 20.72020647757574}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:01,579] Trial 53 finished with value: 0.7736649131197195 and parameters: {'classifier': 'RandomForest', 'n_estimators': 330, 'max_depth': 20.63678770768095}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:02,234] Trial 54 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 230, 'max_depth': 20.65140016312599}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:03,057] Trial 55 finished with value: 0.7671608480790691 and parameters: {'classifier': 'RandomForest', 'n_estimators': 310, 'max_depth': 15.565184116616333}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:04,494] Trial 56 finished with value: 0.7703969392635103 and parameters: {'classifier': 'RandomForest', 'n_estimators': 550, 'max_depth': 21.706150095523466}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:05,402] Trial 57 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 19.793709124310602}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:07,161] Trial 58 finished with value: 0.7720229555236728 and parameters: {'classifier': 'RandomForest', 'n_estimators': 680, 'max_depth': 17.847145203035733}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:07,789] Trial 59 finished with value: 0.7638928742228598 and parameters: {'classifier': 'RandomForest', 'n_estimators': 200, 'max_depth': 22.967417283021508}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:11,980] Trial 60 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1670, 'max_depth': 14.915659469539905}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:13,058] Trial 61 finished with value: 0.7654949784791966 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 31.63834530039639}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:14,263] Trial 62 finished with value: 0.7622588872947552 and parameters: {'classifier': 'RandomForest', 'n_estimators': 470, 'max_depth': 26.329148054821157}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:15,288] Trial 63 finished with value: 0.7736649131197195 and parameters: {'classifier': 'RandomForest', 'n_estimators': 360, 'max_depth': 34.60782893531801}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:16,205] Trial 64 finished with value: 0.7622748286306393 and parameters: {'classifier': 'RandomForest', 'n_estimators': 350, 'max_depth': 34.01284930580652}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:16,973] Trial 65 finished with value: 0.7638689622190339 and parameters: {'classifier': 'RandomForest', 'n_estimators': 280, 'max_depth': 29.098410414247756}. Best is trial 52 with value: 0.7736728837876615.
# [I 2024-09-15 12:18:20,488] Trial 66 finished with value: 0.7769249163079867 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1390, 'max_depth': 11.597604378400925}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:24,332] Trial 67 finished with value: 0.7622509166268133 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1520, 'max_depth': 11.36162273126943}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:24,394] Trial 68 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 969.8770375491907}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:27,925] Trial 69 finished with value: 0.7687709230033476 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1400, 'max_depth': 12.637044234226398}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:31,438] Trial 70 finished with value: 0.772038896859557 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1400, 'max_depth': 10.626541532478129}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:35,038] Trial 71 finished with value: 0.7687709230033476 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1420, 'max_depth': 11.228538408211424}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:38,252] Trial 72 finished with value: 0.7720468675274988 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1290, 'max_depth': 10.146958531748256}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:41,508] Trial 73 finished with value: 0.7752989000478241 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1280, 'max_depth': 10.058132830565002}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:44,681] Trial 74 finished with value: 0.7704128805993943 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1240, 'max_depth': 13.706259309401602}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:48,068] Trial 75 finished with value: 0.7720468675274988 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1340, 'max_depth': 11.48858183931059}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:51,745] Trial 76 finished with value: 0.7687709230033476 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1460, 'max_depth': 12.224060177096296}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:54,712] Trial 77 finished with value: 0.7638928742228598 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1150, 'max_depth': 42.67199593607373}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:58,763] Trial 78 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1590, 'max_depth': 14.518727718789622}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:18:58,834] Trial 79 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 2238221387.9743342}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:02,861] Trial 80 finished with value: 0.772030926191615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1580, 'max_depth': 16.354702344162487}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:06,072] Trial 81 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1250, 'max_depth': 10.021768026220755}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:09,454] Trial 82 finished with value: 0.7671528774111271 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1320, 'max_depth': 11.283316818480946}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:12,168] Trial 83 finished with value: 0.7687629523354057 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1040, 'max_depth': 13.36139994503308}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:16,541] Trial 84 finished with value: 0.7736728837876615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1740, 'max_depth': 10.516647147008223}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:21,442] Trial 85 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1910, 'max_depth': 12.015195464762124}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:26,007] Trial 86 finished with value: 0.772030926191615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1820, 'max_depth': 10.600518326744249}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:28,451] Trial 87 finished with value: 0.7736728837876615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 940, 'max_depth': 35.72187689773852}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:32,936] Trial 88 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1770, 'max_depth': 36.93338488793697}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:35,385] Trial 89 finished with value: 0.7687788936712897 and parameters: {'classifier': 'RandomForest', 'n_estimators': 930, 'max_depth': 41.98180254070628}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:39,694] Trial 90 finished with value: 0.7704208512673363 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1700, 'max_depth': 12.97027270537449}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:42,561] Trial 91 finished with value: 0.7752829587119402 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1130, 'max_depth': 51.2795981729043}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:45,428] Trial 92 finished with value: 0.7655348318189065 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1120, 'max_depth': 57.28872186873696}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:47,829] Trial 93 finished with value: 0.7704049099314524 and parameters: {'classifier': 'RandomForest', 'n_estimators': 940, 'max_depth': 51.17225753996961}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:50,419] Trial 94 finished with value: 0.7655029491471385 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1020, 'max_depth': 24.77032268981099}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:53,176] Trial 95 finished with value: 0.7639008448908019 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1070, 'max_depth': 88.87488818419673}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:58,173] Trial 96 finished with value: 0.7655188904830225 and parameters: {'classifier': 'RandomForest', 'n_estimators': 1970, 'max_depth': 19.069403463938297}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:19:58,244] Trial 97 finished with value: 0.6530926191614858 and parameters: {'classifier': 'SVC', 'svc_c': 0.005095870397725801}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:20:00,459] Trial 98 finished with value: 0.772030926191615 and parameters: {'classifier': 'RandomForest', 'n_estimators': 860, 'max_depth': 47.64838929547453}. Best is trial 66 with value: 0.7769249163079867.
# [I 2024-09-15 12:20:01,529] Trial 99 finished with value: 0.7606408417025347 and parameters: {'classifier': 'RandomForest', 'n_estimators': 400, 'max_depth': 33.00360130481142}. Best is trial 66 with value: 0.7769249163079867.
# Accuracy: 0.7769249163079867
# Best hyperparameters: {'classifier': 'RandomForest', 'n_estimators': 1390, 'max_depth': 11.597604378400925}

# %%
trial
# Out:
# FrozenTrial(number=66, state=1, values=[0.7769249163079867], datetime_start=datetime.datetime(2024, 9, 15, 12, 18, 16, 973174), datetime_complete=datetime.datetime(2024, 9, 15, 12, 18, 20, 488222), params={'classifier': 'RandomForest', 'n_estimators': 1390, 'max_depth': 11.597604378400925}, user_attrs={}, system_attrs={}, intermediate_values={}, distributions={'classifier': CategoricalDistribution(choices=('RandomForest', 'SVC')), 'n_estimators': IntDistribution(high=2000, log=False, low=200, step=10), 'max_depth': FloatDistribution(high=100.0, log=True, low=10.0, step=None)}, trial_id=66, value=None)

# %%
study.best_params
# Out:
# {'classifier': 'RandomForest',
#  'n_estimators': 1390,
#  'max_depth': 11.597604378400925}

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score
rf=RandomForestClassifier(n_estimators=330,max_depth=30)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=30, n_estimators=330)

# %%
y_pred=rf.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[84 15]
#  [24 31]]
# 0.7467532467532467
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.81        99
#            1       0.67      0.56      0.61        55
#
#     accuracy                           0.75       154
#    macro avg       0.73      0.71      0.71       154
# weighted avg       0.74      0.75      0.74       154
